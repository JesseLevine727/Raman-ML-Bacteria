# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Y.csv")

# %%
spectra = data.iloc[:, :-1]
label = data.iloc[:, -1]
print(label)
# Out:
# 0      Corn
# 1      Corn
# 2      Corn
# 3      Corn
# 4      Corn
#        ...
# 894     PAO
# 895     PAO
# 896     PAO
# 897     PAO
# 898     PAO
# Name: Corn, Length: 899, dtype: object

# %%
pca = PCA(n_components=2)  
spectra_pca = pca.fit_transform(spectra)

print(spectra_pca)
# Out:
# [[ 0.78918492  0.87888319]
#  [ 0.06759277  0.5182658 ]
#  [-1.00010724 -0.27781199]
#  ...
#  [ 3.02874201 -0.70562838]
#  [ 3.38558617 -0.53876552]
#  [ 0.77570185 -0.19838944]]

# %%
pca_df = pd.DataFrame(data=spectra_pca, columns=['PC1', 'PC2'])
pca_df['Label'] = label

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='PC1', y='PC2', hue='Label', data=pca_df, palette='dark')
plt.title('PCA of Dataset')
plt.show()
